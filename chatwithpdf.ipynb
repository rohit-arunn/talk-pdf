# %%
import PyPDF2
from langchain_text_splitters import RecursiveCharacterTextSplitter
#from sentence_transformers import SentenceTransformer
import pdfplumber

# %%
import numpy as np

# %%
import importlib.util

libraries = ['PyPDF2', 'langchain_text_splitters', 'sentence_transformers', 'pdfplumber', 'openai', 'openai', 'torch']

for lib in libraries:
    spec = importlib.util.find_spec(lib)
    status = "✅ Found" if spec else "❌ Missing"
    print(f"{lib}: {status}")
# Out:
# PyPDF2: ✅ Found
# langchain_text_splitters: ✅ Found
# sentence_transformers: ✅ Found
# pdfplumber: ✅ Found
# openai: ✅ Found
# openai: ✅ Found
# torch: ❌ Missing

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_text(text)
print(len(chunks))
print(chunks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       1 splitter = RecursiveCharacterTextSplitter(
#       2     chunk_size=500,
#       3     chunk_overlap=100
#       4 )
# ----> 6 chunks = splitter.split_text(text)
#       7 print(len(chunks))
#       8 print(chunks)
#
# NameError: name 'text' is not defined

# %%
with pdfplumber.open("Rohit Arun_Resume_.pdf") as pdf:
    text = ""
    for page in pdf.pages:
        text += page.extract_text()

print(text)
# Out:
# ROHIT ARUN
# +91 6282130156 | Rohit.arun2021@vitstudent.ac.in
# EDUCATION
# VELLORE INSTITUTE OF TECHNOLOGY Vellore, India
# BTech in Electronics and Instrumentation Engineering | CGPA: 8.79/10 2021 - 2025
# Merit Award: Awarded to Top 10 students in the Electronics and Instrumentation Engineering Branch 2022 - 2023
# INTERNSHIPS
# Machine Learning Intern; META SCIFOR TECHNOLOGIES Remote
# A company which specializes in providing innovative digital solutions, empowering businesses with tailored services Oct 2024 - Present
# • Performed data analysis tasks such as indexing and slicing using Python structures and libraries like NumPy, Pandas, and Matplotlib to
# efficiently manage and visualize large datasets; streamlined data processing workflows, reducing analysis time by 20%
# • Applied machine learning fundamentals, including regression, classification, and clustering, to analyse data patterns; improved
# predictive accuracy by 18% enhancing model reliability for future data-driven decisions
# • Developed and optimized Pandas workflows for data cleaning, filtering, and grouping to ensuring accurate and efficient organization of
# structured datasets; reduced data preprocessing time by 25%, enabling reliable insights and timely decision-making for stakeholders
# Machine Learning Intern; FOX TRADING SOLUTIONS Remote
# A company specializing in algorithmic trading and automation solutions Jul - Sep 2024
# • Employed machine learning techniques like regression and gradient boosting to develop and enhance a predictive model to forecast
# bike-sharing demand based on environmental and seasonal factors which fluctuate the sales demand of a new release
# • Conducted data preprocessing, exploration, and visualization using box plots and histograms to identify variables influencing bike
# demand, like location and discounts; optimized feature selection leading to a 15% increase in model accuracy and 10% decrease in errors
# • Developed a diabetes prediction model using patient health records; implemented algorithms like K-Nearest Neighbours, Bagged Trees
# and Support Vector Machine to enhance early diagnosis capabilities which led to a 85% prediction accuracy
# • Built a predictive model using gradient boosting to forecast sales orders, utilizing features like store name, location, and discount
# presence; improved demand forecasting for retail operations and better sales planning
# • Applied data preprocessing techniques such as feature scaling and one-hot encoding while fine-tuning the Gradient Boosting algorithm;
# resulted in a 15% increase in prediction accuracy, enhancing the model's overall performance and reliability
# Hardware design Intern; INDIAN SPACE RESEARCH ORGANISATION (ISRO) Trivandrum, India
# National space agency of India Oct - Dec 2023
# • Designed VHDL-based Field-Programmable Gate Array (FPGA)- Digital-to-Analog Converter (DAC) interface architecture to enhance
# real-time digital signal processing; led to 30% improvement in navigation and control system stability of Orbital re-entry vehicle
# • Configured and analyzed performance of LTC2664 DACs, conducting rigorous testing and data analysis to ensure robust system
# functionality and optimize DAC settings; resulted in reduction of errors by more than 35%
# • Employed simulation tools such as ModelSim and signal visualization tools by verifying and debugging VHDL code to ensure accurate
# digital circuit simulations using real-time data; resulted in considerable improvement in verification efficiency by more than 40%
# • Optimized design efficiency utilizing user-defined functions and detailed timing analysis to address challenges like unexpected delays
# and signal irregularity in FPGA-DAC integration to ensure synchronous operation; improved design efficiency by 25%
# ACADEMIC PROJECTS
# Adaptive Traffic Management: A Real-Time Solution for Urban Intersections Dec 2024
# (Submitted for publication to Machine Learning With Applications; ISSN: 2666-8270)
# • Designed and implemented an Arduino-integrated system for real-time traffic management, leveraging YOLOv5 to detect vehicles and
# adapt signal controls at urban intersections, improving traffic flow efficiency
# • Incorporated machine learning models, including YOLOv5 for object detection and reinforcement learning to optimize dynamic signal
# controls; reduced congestion and decreased waiting times at intersections by up to 20% in simulation tests
# • Developed a cost-effective solution by combining YOLOv5 object detection with an Arduino-based embedded system, demonstrating
# significant improvements in traffic flow management and scalability for implementation across various urban environments
# • Forecasted the impact of the system in large cities, estimating that its implementation could reduce traffic congestion by 25%
# Smart Glasses for Visually Impaired Using Deep Learning Nov 2024
# Year
# • Developed assistive technology using Raspberry Pi 4 and Raspberry Pi Camera to provide real-time object recognition and
# environmental descriptions, enabling visually impaired users to better navigate their surroundings
# • Integrated YOLOv5 deep learning model and OpenCV for higher detection accuracy; achieved a 23% improvement in detection
# accuracy and reduced processing time by 13%, ensuring minimal delay between object detection and audio feedback
# • Implemented text generation with pre-built templates and Google Text-to-Speech conversion to deliver concise, and contextually
# relevant auditory feedback to visually impaired users; enhancing their spatial awareness and ability to interact with the environment
# • Optimized system for real-time processing, delivering seamless auditory descriptions via earphones to describe surroundings
# Comparative Analysis of IIR Butterworth and FIR Filters for Noise Signal Separation Jul 2023• Designed IIR lowpass Butterworth filter and an FIR lowpass filter in MATLAB by utilizing filter design functions and frequency domain
# analysis; achieved optimal signal separation among mixed noise signals of 1000 Hz and 400 Hz
# • Conducted performance analysis of both filters and observed that FIR filter provided superior clarity and noise signal suppression for
# low-frequency signals; presented findings with graphical data including time-domain plots and frequency response to 40+ students
# Real-Time Weather Dashboard Using WeatherAPI Jun 2023
# • Utilized HTML, CSS and Java Script to develop a real-time weather information website; integrated WeatherAPI which uses an API
# key to gather data from any location globally in JSON format to provide weather details such as temperature, dynamically
# • Optimized website performance through regular location-based testing, used Fetch API for asynchronous requests and implemented 5-
# minute request intervals; led to smooth data retrieval, accurate and up-to-date weather information and reduced load time by 30%
# • Employed CSS grids and adaptive layouts to ensure cross-browser compatibility across 5+ devices including desktops and iPads
# EXTRA-CURRICULAR ACTIVITIES
# Editorial Head, Soft Computing Research Society, VIT Jan 2024 - Present
# • Led a team of 4 editors and initiated outreach activities such as cultivating partnerships through 5 collaborations with academic and
# industry experts such as Harsad Punghera, Data Science Lead at Atsuya Technologies; improved chapter’s offerings by 50+%.
# • Organised a session focused on backend development with Flask; attended by 70+ students
# • Arranged an event on GitHub and Docker by the technical head of SCRS, for over 50 students, where he shared his expertise and shared
# an extensive roadmap on how to start their journey on development
# • Led an online event on utilizing AI speech technology for special needs education, drawing 100+ attendees, and featuring experts like
# Anant Vaish and Mohammed Mujataba, fostering discussions on technological advancements in education
# • Conceptualized a social media campaign and executed editorial strategies like targeted outreach and tailored content distribution; led to
# a 30% increase in post interaction and 10% increase in readership of the Society’s Journal Advancements in communication and Systems.
# Web Development And AI/ML Domain, Soft Computing Research Society, VIT Feb - Dec 2023
# • Organized 2 workshops on machine learning for lung-cancer prediction and a session on generative AI and AI integration in vehicles;
# benefited 60+ students by providing exposure to 5 expert speakers and industry insights
# • Coordinated a web development training session led by Arnav Sharma from Scaler to enhance the student’s technical skills in web
# framework; attended by 30+ society members
# • Spearheaded a collaborative project to develop a prototype AI-based web application, providing hands-on experience in integrating
# machine learning models with web technologies, fostering practical learning for 40+ students
# Core Committee member, Creation Labs, VIT Feb 2023 - Jan 2024
# • Organized 2 workshops on generative AI and Github for 60+ students across computer science and mechanical engineering departments
# • Designed and implemented a project incubation framework focused on AI and automation that guided 10+ student teams in pitching
# innovative ideas, securing mentorship, and developing prototypes for real-world applications
# • Facilitated cross-departmental collaboration by coordinating weekly brainstorming sessions, encouraging interdisciplinary ideas;
# fostered a culture of innovation that resulted in the successful development of 5+ collaborative projects
# TECHNICAL SKILLS
# Programming: Python, Java, VHDL
# Machine Learning Frameworks: Scikit-Learn, TensorFlow, OpenCV
# Data Science: Pandas, NumPy, Matplotlib
# Software: MATLAB, Simulink
# ADDITONAL INFORMATION
# Languages: Proficient in English, Malayalam and Hindi
# Hackathon: Led a team of 4 to develop a smart irrigation system using Esp32 microcontroller and various sensors to monitor soil moisture
# levels, temperature, and plant health while optimising water usage and promoting efficient irrigation practise, secured 2nd place
# Community Engagement: Core Committee Member of Becoming I Foundation (VIT)
# Online Courses: Machine Learning Specialization (Coursera, 2023)
# Interests: Competing in football and athletics since high school
