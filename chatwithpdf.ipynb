# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit-arunn/talk-pdf/blob/main/chatwithpdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import PyPDF2

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
file_path = "/content/Rohit_Arun_Resume_.pdf"

with open(file_path, "rb") as f:
    reader = PyPDF2.PdfReader(f)

    text = ""
    for page in reader.pages:
        text += page.extract_text()

print(text)
# Out:
# ROHIT ARUN
# +1 (213) 879 -7011  | rohitaru@usc.edu  | LinkedIn
#  EDUCATION
#
# UNIVERSITY OF SOUTHER N CALIFORNIA                                        Los Angeles, CA
# MS in Applied Data Science                                     2026  - 2027
#  VELLORE INSTITUTE OF TECHNOLOGY                                            Vellore, India
# BTech in Electronics and Instrumentation Engineering | CGPA: 8.7 7/10                                                            2021 - 2025
#
# INTERNSHIP  EXPERIENCE
# Data Science Intern;  IBS SOFTWARE                           On-site
# World leader in providing software solutions for the aviation industry                         Jun 2024 – Nov 2025
# • Built an “evolutionary learning” based  cargo optimization solution for aircraft Unit Load Devices ( ULD) focused on efficient space
# utilization and 3D box placement .
# • Designed a custom Genetic Algorithm –based learning framework to evolve box sequencing and orientation policies, using fitness
# functions calculated based on  effective space utilization and stability constraints .
# • Proposed and implemented a novel hybrid packing approach combining evolutionary learning with fixed spatial rules, enabling h ighly
# intelligent reuse of all vacant space and constraint -aware placements.
# • Developed an interactive 3D visualization to render the ULD loaded with the most optimized box arrangement, allowing clear
# understanding of space utilization, and also presented the results to the cargo operations team at IBS Software.
#
# AI/ML  Intern;  META SCIFOR TECHNOLOGIES                          Hybrid
# A company which specializes in providing innovative digital solutions, empowering businesses with tailored services    Oct 2024 – Feb 2025
# • Performed data analysis tasks such as indexing and slicing using Python structures and libraries like NumPy, Pandas, and Matp lotlib to
# efficiently manage and visualize large datasets; streamlined data processing workflows, reducing analysis time by 20%.
# • Developed and evaluated a lung cancer prediction system using machine learning and neural networks, comparing Logistic Regres sion,
# Random Forest, XGBoost, and PyTorch -based MLP models, with XGBoost achieving the highest diagnostic performance
# • Developed a diabetes prediction model using patient health records; implemented algorithms like K -Nearest Neighbors , Bagged Trees
# and Support Vector Machine to enhance early diagnosis capabilities which led to a 85% prediction accuracy
#
# Machine Learning  Intern ; FOX TRADING SOLUTIONS                                                         Remote
# A company specializing in algorithmic trading and automation solutions                                                   Jul - Sep 2024
# • Employed machine learning techniques like regression and gradient boosting to develop and enhance a predictive model to forec ast bike
# sharing  demand based on environmental and seasonal factors which fluctuate the sales demand of a new release
# • Built a predictive model using gradient boosting to forecast sales orders, utilizing features like store name, location, and discount
# presence; improved demand forecasting for retail operations and better sales planning
# • Applied data preprocessing techniques such as feature scaling and one -hot encoding while fine -tuning the Gradient Boosting algorithm;
# resulted in a 15% increase in prediction accuracy, enhancing the model's overall performance and reliability
# Hardware design Intern; INDIAN SPACE RESEARCH ORGANISATION ( ISRO)         Trivandrum, India
# National space agency of India                                                                            Oct - Dec 2023
# • Designed VHDL -based Field -Programmable Gate Array (FPGA) - Digital -to-Analog Converter (DAC) interface architecture to enhance
# real-time digital signal processing; led to an around 30% improvement in control system stability of Orbital Re-entry Vehicle (ORV).
# • Configured and analyzed performance of LTC2664 DACs, conducting rigorous testing and data analysis to ensure robust system
# functionality and optimize DAC settings; resulted in reduction of errors by more than 35%
# • Employed simulation tools such as ModelSim and signal visualization tools by verifying and debugging VHDL code to ensure accu rate
# digital circuit simulations using real -time data; resulted in considerable improvement in verification efficiency by more than  40% , also
# performed detailed timing analysis to address challenges like unexpected delays and signal irregularity in FPGA -DAC integration to
# ensure synchronous operation; improved design efficiency by 25%.
#
# PROJECTS
# Integrated Smart Irrigation and Plant Health Monitoring System                                                                                                May 2025
# • Designed and implemented a real -time plant health monitoring and smart irrigation prototype using Arduino UNO, DHT11, FC -28 soil
# moisture sensor, and SG90 servo motor.
# • Developed a multi -class classification model using Random Forest classifier to detect  various plant conditions based on live
# environmental data  collected locally .
# • Created a Flask -based REST API and web dashboard with Chart.js to visualize sensor data in real time and display plant health trends
# dynamically.
# • Integrated automated email alerts using SMTP and achieved 95% model accuracy on a  custom  dataset of 200 sensor -based observations.
# Smart Glasses for Visually Impaired Using Deep Learning Techniques              Jul 2024 - Nov 2024
# • Developed assistive technology using Raspberry Pi 4 and Raspberry Pi Camera to provide real -time object recognition and
# environmental descriptions, enabling visually impaired users to better navigate their surroundings
# • Integrated YOLOv 3 deep learning model and OpenCV for higher detection accuracy; achieved a 23% improvement in detection
# accuracy and reduced processing time by 13%, ensuring minimal delay between object detection and audio feedback
# • Implemented text generation with pre -built templates and  Python’s  Text-to-Speech library  to deliver concise, and contextually relevant
# auditory feedback to visually impaired users; enhancing their spatial awareness and ability to interact with the environment
# • Optimized system for real -time processing, delivering seamless auditory descriptions via earphones to describe surroundings
#
# Comparative Analysis of IIR Butterworth and FIR Filters for Noise Signal Separation                                                             Jul 2023
# • Designed IIR lowpass Butterworth filter and an FIR lowpass filter in MATLAB by utilizing filter design functions and frequenc y
# domain analysis; achieved optimal signal separation among mixed noise signals of 1000 Hz and 400 Hz
# • Conducted performance analysis of both filters and observed that FIR filter provided superior clarity and noise signal suppre ssion for
# low-frequency signals .
#
# Real -Time Weather Dashboard Using WeatherAPI                                                                                                     Jun 2023  – Jul 2023
# • Utilized HTML, CSS and Java Script to develop a real -time weather information website; integrated WeatherAPI which uses an API
# key to gather data from any location globally in JSON format to provide weather details such as temperature, dynamically
# • Optimized website performance through regular location -based testing, used Fetch API for asynchronous requests and implemented 5 -
# minute request intervals; led to smooth data retrieval, accurate and up -to-date weather information and reduced load time by 3 0%
# • Employed CSS grids and adaptive layouts to ensure cross -browser compatibility across 4 devices including desktops and iPads
#
# EXTRA -CURRICULAR ACTIVITIES
# Editorial Head, Soft Computing Research Society, VIT                                                                                               Jan 2024 – Feb 2025
# • Led a team of 4 editors and initiated outreach activities such as cultivating partnerships through 5 collaborations with acad emic and
# industry experts.
# • Organized  a session focused on backend development with Flask; attended by 70+ students
# • Arranged an event on GitHub and Docker by the technical head of SCRS, for over 50 students, where he shared his expertise and
# shared an extensive roadmap on how to start their journey on development
# • Led an online event on utilizing AI speech technology for special needs education, drawing 100+ attendees, and featuring expe rts in
# the field ; fostering discussions on technological advancements in education
#
# Web Development And AI/ML Domain, Soft Computing Research Society, VIT                                                              Feb - Dec 2023
# • Organized 2 workshops on machine learning for lung -cancer prediction and a session on generative AI and AI integration in vehicles;
# benefited 60+ students by providing exposure to 5 expert speakers and industry insights
# • Coordinated a web development training session to enhance the student’s technical skills in web framework; attended by 30+ so ciety
# members
# • Spearheaded a collaborative project to develop a prototype AI -based web application, providing hands -on experience in integrating
# machine learning models with web technologies, fostering practical learning for 40+ students
#
# Core Committee member, Creation Labs, VIT                                                              Feb 2023 - Jan 2024
# • Organized 2 workshops on generative AI and GitHub  for 60+ students across computer science and mechanical engineering
# departments
# • Designed and implemented a project incubation framework focused on AI and automation that guided 10+ student teams in pitchin g
# innovative ideas, securing mentorship, and developing prototypes for real -world applications
#
# TECHNICAL SKILLS
# Programming:  Python,  Java, VHDL
# Machine Learning Frameworks:  Scikit -Learn, TensorFlow , PyTorch
# Data Science:  Pandas, NumPy, Matplotlib
# Software:  MATLAB, Simulink
#
# ADDITIONAL INFORMATION
# Languages:  Proficient in English, Malayalam and Hindi
# Hackathon:  Led a team of 4 to develop a smart irrigation system using Esp32 microcontroller and various sensors to monitor soil moisture
# levels, temperature, and plant health while optimizing  water usage and promoting efficient irrigation practice , secured 2nd place .
# Merit:  Awarded to the Top 10 students in the Electronics and Instrumentation Engineering Branch (VIT)  2022 -23
# Community Engagement: Core Committee Member of Becoming I Foundation (VIT)
# Online Courses: Machine Learning Specialization (Coursera, 2023)
# Interests:  Competing in football and athletics since high school

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_9786/1407318800.py in <cell line: 0>()
# ----> 1 from langchain_text_splitters import RecursiveCharacterTextSplitter
#
# ModuleNotFoundError: No module named 'langchain_text_splitters'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_text(text)
print(len(chunks))
print(chunks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9786/2730878823.py in <cell line: 0>()
# ----> 1 splitter = RecursiveCharacterTextSplitter(
#       2     chunk_size=500,
#       3     chunk_overlap=100
#       4 )
#       5
#
# NameError: name 'RecursiveCharacterTextSplitter' is not defined
